# %% [markdown]
# # Forecast

# %%
import pyaiutils as pai
import pandas as pd

# %%
DATA_DIR = './downloads/pre-processed'

# %%
from tensorflow.keras import backend as K


class Metric:
    """Class with the metrics to evaluate the forecast
    """

    @staticmethod
    def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    
    @staticmethod
    def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall
    
    @staticmethod
    def f1_m(y_true, y_pred):
        precision = precision_m(y_true, y_pred)
        recall = recall_m(y_true, y_pred)
        return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
import tensorflow as tf
import numpy as np
import sklearn
import pickle


class Model:
    
    def __init__(self, model: str, scaler: str):
        """Class for the neural network model.
        
        Parameters
        ----------
        model : str
            Path to the model file
        scaler : str
            Path to the scaler file
        """
        self._model = self._load_model(model)
        self._scaler = self._load_scaler(scaler)
        
    def _load_model(self, path: str) -> tf.keras.Model:
        """Load the model
        
        Parameters
        ----------
        path : str
            Path to the model file

        Returns
        -------
        tf.keras.Model
            Keras model
        """
        try:
            return tf.keras.models.load_model(
                path,
                custom_objects = {
                    'precision_m': Metric.precision_m,
                    'recall_m': Metric.recall_m,
                    'f1_m': Metric.f1_m
                }
            )
        except OSError:
            raise OSError(f'Model not found in {path}')
    
    def _load_scaler(self, path: str):
        """Load the scaler
        
        Parameters
        ----------
        path : str
            Path to the scaler file

        Returns
        -------
        sklearn.preprocessing.*
            Scikit-learn scaler
        """
        try:
            with open(path, 'rb') as f:
                return pickle.load(f)
        except FileNotFoundError:
            raise FileNotFoundError(f'Scaler not found in {path}')
        
    def _transform(self) -> None:
        """Abstract method
        """
        raise NotImplementedError

    def predict(self, x: np.ndarray):
        """Predict from x
        
        Parameters
        ----------
        x : np.ndarray
            Array expected for model entry

        Returns
        -------
        np.ndarray
            x forecast result
        """
        return self._model.predict(self._transform(x))
    
    def evaluate(
        self,
        x_test: np.ndarray,
        y_test: np.ndarray,
        class_names: [str],
        path: str = None
    ) -> np.ndarray:
        y_pred = self.predict(x_test)
        y_true = np.argmax(y_test, axis=1)
        y_pred = np.argmax(y_pred, axis=1)
        pai.plot_graphics(y_true, y_pred, class_names=class_names, save_path=path)
        display(pai.get_metrics(y_true, y_pred, class_names=class_names, save_path=path))

# %%
class MLP(Model):
    def _transform(self, x: np.ndarray) -> np.ndarray:
        """x scale
        
        Parameters
        ----------
        x : np.ndarray
            Array expected for model entry

        Returns
        -------
        np.ndarray
            x scaled
        """
        return self._scaler.transform(x)

# %%
class CNN(Model):
    def _transform(self, x: np.ndarray) -> np.ndarray:
        """x scale
        
        Parameters
        ----------
        x : np.ndarray
            Array expected for model entry

        Returns
        -------
        np.ndarray
            x scaled
        """
        x = self._scaler.transform(x)
        return np.reshape(x, (x.shape[0], 1, x.shape[1]))

# %%
def replace(df: pd.DataFrame, rules: {}) -> pd.DataFrame:    
    for rule in rules.values():
        cols = rule['cols']
        df[cols] = df[cols].replace(rule['replaces'], regex=rule['regex'])
    return df

# %% [markdown]
# ### Examples

# %% [markdown]
# COVID/NÃO-COVID
#
# Expected entries for the model (In expected order)

# %%
# 'Apresentou perda de olfato e/ou paladar?',
# 'Apresentou cefaléia?',
# 'Apresentou adinamia?',
# 'Apresentou dores musculares e/ou nas articulações?',
# 'Apresentou calafrios?',
# 'Apresentou tontura?',
# 'Apresentou sudorese noturna?',
# 'Apresentou irritabilidade/confusão?',
# 'Possui neoplasia (tumor sólido ou hematológico)?',
# 'Possui doença respiratória crônica?',
# 'Gestante?',
# 'Desfecho (cura/óbito)'
symptoms = [
    'Apresentou febre?', # Febre
    'Apresentou tosse?', # Tosse
    'Apresentou dor de garganta?', # Dor de garganta
    'Apresentou dispneia?', # Dispneia // falta de ar
    'Apresentou desconforto respiratório?', # Desconforto respiratório
    'Saturação de Oxigênio abaixo de 95%?', # Saturação de O2 abaixo de 95%
    'Apresentou diarreia?', # Diarreia
#     'Apresentou náusea/vômito?', # Vômito
]
comorbidities = [
    'É puérpera?', # Puérpera // mulher que deu à luz há bem pouco tempo.
    'Possui doença cardiovascular?', # Doença cardiovascular // coração
#     'Possui doença hematológica?', # Componentes do sangue
    'Portador de alteração cromossômica?', # Síndrome de Down
    'Possui doença hepática?', # Doença hepática // fígado
#     'ASMA', # Asma
#     'Possui diabetes mellitus?', Diabetes
    'Possui doença neurológica?', # Doença neurológica // sistema nervoso
    'Possui pneumopatia?', # Pneumopatia // pulmão
    'Possui imunodeficiência ou imunodepressão?', # Imunodeficiência ou Imunodepressão // sistema imunológico
    'Possui doença renal?', # Doença renal
    'Possui obesidade?', # Obesidade
]
x_cols = [
    *symptoms,
    *comorbidities,
    'Sexo', # Sexo
    'Idade em anos', # Idade
]
y_cols = ['Classificado como COVID-19?'] # Classificação

# %% [markdown]
# |Sintomas|Comorbidades|CS_SEXO|NU_IDADE_N|CLASSI_FIN|
# |--|--|--|--|--|
# |0. NaN|0. NaN|||
# |1. Sim|1. Sim|1: Masculino||0. Não Covid|
# |2. Não|2. Não|2: Feminino||1. Covid|
# |9. Ignorado|9. Ignorado||||

# %% [markdown]
# Open dataset

# %%
df = pd.read_excel(f'{DATA_DIR}/Mapping_RT-PCR_Final_11.02.2021.xlsx')
df = df[[*x_cols, *y_cols]]
df
# Out:
#       Apresentou febre? Apresentou tosse? Apresentou dor de garganta?  \
# 0                   NÃO               NÃO                         NÃO
# 1                   NÃO               SIM                         NÃO
# 2                   NÃO               NÃO                         NÃO
# 3                   NÃO               NÃO                         NÃO
# 4                   NÃO               NÃO                         NÃO
# ...                 ...               ...                         ...
# 11000               NÃO               NÃO                         NÃO
# 11001               NÃO               NÃO                         NÃO
# 11002               NÃO               NÃO                         NÃO
# 11003               NÃO               NÃO                         NÃO
# 11004               NÃO               NÃO                         NÃO
#
#       Apresentou dispneia? Apresentou desconforto respiratório?  \
# 0                      NÃO                                  NÃO
# 1                      NÃO                                  NÃO
# 2                      NÃO                                  NÃO
# 3                      NÃO                                  NÃO
# 4                      NÃO                                  NÃO
# ...                    ...                                  ...
# 11000                  NÃO                                  NÃO
# 11001                  NÃO                                  NÃO
# 11002                  NÃO                                  NÃO
# 11003                  NÃO                                  NÃO
# 11004                  NÃO                                  NÃO
#
#       Saturação de Oxigênio abaixo de 95%? Apresentou diarreia? É puérpera?  \
# 0                                      S/I                  NÃO         S/I
# 1                                      S/I                  NÃO         S/I
# 2                                      S/I                  NÃO         S/I
# 3                                      S/I                  NÃO         S/I
# 4                                      S/I                  NÃO         S/I
# ...                                    ...                  ...         ...
# 11000                                  S/I                  NÃO         S/I
# 11001                                  S/I                  NÃO         S/I
# 11002                                  S/I                  NÃO         S/I
# 11003                                  S/I                  NÃO         S/I
# 11004                                  S/I                  NÃO         S/I
#
#       Possui doença cardiovascular? Portador de alteração cromossômica?  \
# 0                               NÃO                                 NÃO
# 1                               NÃO                                 NÃO
# 2                               NÃO                                 NÃO
# 3                               NÃO                                 NÃO
# 4                               NÃO                                 NÃO
# ...                             ...                                 ...
# 11000                           NÃO                                 NÃO
# 11001                           NÃO                                 NÃO
# 11002                           NÃO                                 NÃO
# 11003                           NÃO                                 NÃO
# 11004                           NÃO                                 NÃO
#
#       Possui doença hepática? Possui doença neurológica? Possui pneumopatia?  \
# 0                         NÃO                        NÃO                 NÃO
# 1                         NÃO                        NÃO                 NÃO
# 2                         NÃO                        NÃO                 NÃO
# 3                         NÃO                        NÃO                 NÃO
# 4                         NÃO                        NÃO                 NÃO
# ...                       ...                        ...                 ...
# 11000                     NÃO                        NÃO                 NÃO
# 11001                     NÃO                        NÃO                 NÃO
# 11002                     NÃO                        NÃO                 NÃO
# 11003                     NÃO                        NÃO                 NÃO
# 11004                     NÃO                        NÃO                 NÃO
#
#       Possui imunodeficiência ou imunodepressão? Possui doença renal?  \
# 0                                            NÃO                  NÃO
# 1                                            NÃO                  NÃO
# 2                                            NÃO                  NÃO
# 3                                            NÃO                  NÃO
# 4                                            NÃO                  NÃO
# ...                                          ...                  ...
# 11000                                        NÃO                  SIM
# 11001                                        NÃO                  NÃO
# 11002                                        NÃO                  NÃO
# 11003                                        NÃO                  NÃO
# 11004                                        NÃO                  NÃO
#
#       Possui obesidade? Sexo  Idade em anos Classificado como COVID-19?
# 0                   NÃO    M           54.0                         NÃO
# 1                   NÃO    M           34.0                         NÃO
# 2                   NÃO    M           36.0                         NÃO
# 3                   NÃO    M           59.0                         NÃO
# 4                   NÃO    F           23.0                         NÃO
# ...                 ...  ...            ...                         ...
# 11000               NÃO    M           40.0                         NÃO
# 11001               NÃO    M           23.0                         NÃO
# 11002               NÃO    M           23.0                         NÃO
# 11003               NÃO    M           27.0                         NÃO
# 11004               NÃO    M           54.0                         NÃO
#
# [11005 rows x 19 columns]

# %% [markdown]
# Mapping attributes expected by the model

# %%
rules = {
    0: {
        'cols': [*symptoms, *comorbidities],
        'replaces': {r'^SIM': 1, r'^NÃO': 2, r'^S/I': 0},
        'regex': True
    },
    1: {
        'cols': 'Sexo',
        'replaces': {r'^M': 1, r'^F': 2},
        'regex': True
    },
    2: {
        'cols': 'Classificado como COVID-19?',
        'replaces': {r'^SIM': 1, r'^NÃO': 0, r'^REPETIR': np.nan, r'^INCONCLUSIVO': np.nan},
        'regex': True
    }
}

# %%
df = replace(df, rules)
df = df[~df.isnull().any(axis=1)]
df
# Out:
#        Apresentou febre?  Apresentou tosse?  Apresentou dor de garganta?  \
# 0                      2                  2                            2
# 1                      2                  1                            2
# 2                      2                  2                            2
# 3                      2                  2                            2
# 4                      2                  2                            2
# ...                  ...                ...                          ...
# 11000                  2                  2                            2
# 11001                  2                  2                            2
# 11002                  2                  2                            2
# 11003                  2                  2                            2
# 11004                  2                  2                            2
#
#        Apresentou dispneia?  Apresentou desconforto respiratório?  \
# 0                         2                                     2
# 1                         2                                     2
# 2                         2                                     2
# 3                         2                                     2
# 4                         2                                     2
# ...                     ...                                   ...
# 11000                     2                                     2
# 11001                     2                                     2
# 11002                     2                                     2
# 11003                     2                                     2
# 11004                     2                                     2
#
#        Saturação de Oxigênio abaixo de 95%?  Apresentou diarreia?  \
# 0                                         0                     2
# 1                                         0                     2
# 2                                         0                     2
# 3                                         0                     2
# 4                                         0                     2
# ...                                     ...                   ...
# 11000                                     0                     2
# 11001                                     0                     2
# 11002                                     0                     2
# 11003                                     0                     2
# 11004                                     0                     2
#
#        É puérpera?  Possui doença cardiovascular?  \
# 0                0                              2
# 1                0                              2
# 2                0                              2
# 3                0                              2
# 4                0                              2
# ...            ...                            ...
# 11000            0                              2
# 11001            0                              2
# 11002            0                              2
# 11003            0                              2
# 11004            0                              2
#
#        Portador de alteração cromossômica?  Possui doença hepática?  \
# 0                                        2                        2
# 1                                        2                        2
# 2                                        2                        2
# 3                                        2                        2
# 4                                        2                        2
# ...                                    ...                      ...
# 11000                                    2                        2
# 11001                                    2                        2
# 11002                                    2                        2
# 11003                                    2                        2
# 11004                                    2                        2
#
#        Possui doença neurológica?  Possui pneumopatia?  \
# 0                               2                    2
# 1                               2                    2
# 2                               2                    2
# 3                               2                    2
# 4                               2                    2
# ...                           ...                  ...
# 11000                           2                    2
# 11001                           2                    2
# 11002                           2                    2
# 11003                           2                    2
# 11004                           2                    2
#
#        Possui imunodeficiência ou imunodepressão?  Possui doença renal?  \
# 0                                               2                     2
# 1                                               2                     2
# 2                                               2                     2
# 3                                               2                     2
# 4                                               2                     2
# ...                                           ...                   ...
# 11000                                           2                     1
# 11001                                           2                     2
# 11002                                           2                     2
# 11003                                           2                     2
# 11004                                           2                     2
#
#        Possui obesidade?  Sexo  Idade em anos  Classificado como COVID-19?
# 0                      2   1.0           54.0                          0.0
# 1                      2   1.0           34.0                          0.0
# 2                      2   1.0           36.0                          0.0
# 3                      2   1.0           59.0                          0.0
# 4                      2   2.0           23.0                          0.0
# ...                  ...   ...            ...                          ...
# 11000                  2   1.0           40.0                          0.0
# 11001                  2   1.0           23.0                          0.0
# 11002                  2   1.0           23.0                          0.0
# 11003                  2   1.0           27.0                          0.0
# 11004                  2   1.0           54.0                          0.0
#
# [10492 rows x 19 columns]

# %% [markdown]
# Get only covid cases

# %%
df = df[df['Classificado como COVID-19?'] == 1]
df.shape
# Out:
# (767, 19)

# %% [markdown]
# Save x,y

# %%
df[x_cols].to_csv(f'{DATA_DIR}/mapping_rt-pcr_final_oc_11.02.2021-xcols.csv', index=False)
df[y_cols].to_csv(f'{DATA_DIR}/mapping_rt-pcr_final_oc_11.02.2021-ycols.csv', index=False)

# %% [markdown]
# - pm: path to the model
# - ps: path to the scaler

# %%
# pm = './models/mlp_covid.h5'
# ps = './scalers/scaler_covid.pkl'
# covid = MLP(model=pm, scaler=ps)

pm = './models/cnn_covid.h5'
ps = './scalers/scaler_covid.pkl'
covid = CNN(model=pm, scaler=ps)

# %% [markdown]
# Prediction

# %%
covid.evaluate(
    x_test=df[x_cols],
    y_test=tf.keras.utils.to_categorical(df[y_cols]),
    class_names=['N-Covid', 'Covid'],
    path='./downloads/results/onlycovid'
)
# Out:
# /mnt/e/ferraz/dev/my/desk/pcr-analysis/venv/lib/python3.8/site-packages/pyaiutils/__init__.py:187: RuntimeWarning: invalid value encountered in true_divide
#   perc_cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# None
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-23-d46dfa7d1a9c> in <module>
# ----> 1 covid.evaluate(
#       2     x_test=df[x_cols],
#       3     y_test=tf.keras.utils.to_categorical(df[y_cols]),
#       4     class_names=['N-Covid', 'Covid'],
#       5     path='./downloads/results/onlycovid'
#
# <ipython-input-4-3ff2b5793d97> in evaluate(self, x_test, y_test, class_names, path)
#      94         y_true = np.argmax(y_test, axis=1)
#      95         y_pred = np.argmax(y_pred, axis=1)
# ---> 96         pai.plot_graphics(y_true, y_pred, class_names=class_names, save_path=path)
#      97         display(pai.get_metrics(y_true, y_pred, class_names=class_names, save_path=path))
#
# /mnt/e/ferraz/dev/my/desk/pcr-analysis/venv/lib/python3.8/site-packages/pyaiutils/__init__.py in plot_graphics(y_true, y_pred, class_names, save_path)
#     384     display(plot_confusion_matrix(y_true, y_pred, visualize=True,
#     385                                   normalize=True, class_names=class_names, save_path=save_path))
# --> 386     display(plot_auc_roc_multi_class(y_true, y_pred,
#     387                                      class_names=class_names, save_path=save_path))
#     388     display(plot_prc_auc_multiclass(y_true, y_pred,
#
# /mnt/e/ferraz/dev/my/desk/pcr-analysis/venv/lib/python3.8/site-packages/pyaiutils/__init__.py in plot_auc_roc_multi_class(y_test, y_pred, class_names, save_path)
#     239
#     240     if(len(y_pred.shape) == 1):
# --> 241         y_pred = multiclass_predict_1d_to_nd(y_pred, np.unique(y_test))
#     242         y_test = multiclass_predict_1d_to_nd(y_test, np.unique(y_test))
#     243     # else:
#
# /mnt/e/ferraz/dev/my/desk/pcr-analysis/venv/lib/python3.8/site-packages/pyaiutils/__init__.py in multiclass_predict_1d_to_nd(y_, unique_labels)
#      12 def multiclass_predict_1d_to_nd(y_, unique_labels):
#      13     if(len(np.unique(y_)) != len(unique_labels)):
# ---> 14         y_ = y_.argmax(axis=1)
#      15
#      16     y_new = []
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
y_pred = covid.predict(df[x_cols])
y_pred

# %%
y_pred = np.argmax(y_pred, axis=1)
y_pred

# %%
np.unique(y_pred, return_counts=True)
